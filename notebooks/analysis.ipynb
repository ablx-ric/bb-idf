# %% [markdown]
# # Benchmark: TF-IDF vs Custom Algorithm

# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

df = pl.read_csv("../data/results/benchmark.csv")
df

# %%
fig, ax = plt.subplots(figsize=(8, 4))
sns.barplot(data=df.to_pandas(), x="algorithm", y="fit_time_s")
ax.set_title("Tiempo de ajuste por algoritmo")
plt.show()
